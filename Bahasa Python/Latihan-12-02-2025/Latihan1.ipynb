# %%
pin_benar = 1234
pin_dimasukkan = int(input("Masukkan PIN anda: "))

if pin_dimasukkan == pin_benar:
  print("Autentikasi berhasil!")
else:
    print("PIN salah. Akses ditolak.")
# Out:
# Masukkan PIN anda: 1234
# Autentikasi berhasil!
