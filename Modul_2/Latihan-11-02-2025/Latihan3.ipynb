# %%
harga_tiket = 150000
jumlah_penumpang = 3
total_harga = harga_tiket * jumlah_penumpang

print("Harga Tiket per Orang: Rp", harga_tiket)
print("Jumlah Penumpang:", jumlah_penumpang)
print("Total Harga Tiket: Rp", total_harga)
# Out:
# Harga Tiket per Orang: Rp 150000
# Jumlah Penumpang: 3
# Total Harga Tiket: Rp 450000
