# %%
saldo_akun = 100000
jumlah_setoran = int(input("Masukkan jumlah setoran: "))
saldo_akun = saldo_akun + jumlah_setoran
print ("Saldo baru Anda adalah: ", saldo_akun)
# Out:
# Masukkan jumlah setoran: 200000
# Saldo baru Anda adalah:  300000
